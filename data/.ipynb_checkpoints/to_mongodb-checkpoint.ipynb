# %%
# Dependencies and boilerplate
import pandas as pd
import csv
import pymongo
import json

# %%
file_name = "airports.csv"

df = pd.read_csv(file_name, encoding="utf-8")

df
# Out:
#     faa_site_number loc_id                        airport_name  \
# 0          13487.*A    ACY                  ATLANTIC CITY INTL
# 1          14460.*A    WWD                     CAPE MAY COUNTY
# 2          13966.*A    47N                 CENTRAL JERSEY RGNL
# 3          13578.*A    CDW                        ESSEX COUNTY
# 4          14448.*A    4N1                      GREENWOOD LAKE
# 5         13796.2*A    N81                      HAMMONTON MUNI
# 6          13890.*A    N12                            LAKEWOOD
# 7          13911.*A    N07                        LINCOLN PARK
# 8          13914.*A    LDJ                              LINDEN
# 9          14010.*A    MIV                      MILLVILLE MUNI
# 10         13524.*A    BLM                  MONMOUTH EXECUTIVE
# 11         14031.*A    MMU                     MORRISTOWN MUNI
# 12         14052.*A    EWR                 NEWARK LIBERTY INTL
# 13         14109.*A    26N                     OCEAN CITY MUNI
# ...

# %%
airport_dict = df.to_dict(orient="records")

json.dumps(airport_dict)
# Out:
# '[{"faa_site_number": "13487.*A", "loc_id": "ACY", "airport_name": "ATLANTIC CITY INTL", "associated_city": "ATLANTIC CITY", "state": "NJ", "region": "AEA", "ado": "HAR", "use": "PU", "lat_dms": "39-27-27.3000N", "long_dms": "074-34-37.8000W", "lat_dd": 39.45758333, "long_dd": -74.57716667, "airport_ownership": "PU", "part_139": "I C S 12/1974", "npias_service_level": "Primary", "npias_hub_type": "Small", "airport_control_tower": "Y", "fuel": "100LLA    A++", "other_services": "CHTR", "based_aircraft_total": 13, "total_operations": 53506}, {"faa_site_number": "14460.*A", "loc_id": "WWD", "airport_name": "CAPE MAY COUNTY", "associated_city": "WILDWOOD", "state": "NJ", "region": "AEA", "ado": "HAR", "use": "PU", "lat_dms": "39-00-30.1300N", "long_dms": "074-54-30.6400W", "lat_dd": 39.00836944, "long_dd": -74.90851111, "airport_ownership": "PU", "part_139": NaN, "npias_service_level": "General Aviation", "npias_hub_type": NaN, "airport_control_tower": "N", "fuel": "100LLA", "other_servi
# ...

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
#client.drop_database(db)
db = client.travel
collection = db.airports

# %%
db.collection.insert_many(airport_dict)

# %%
airporting = list(db.collection.find())
df = pd.DataFrame(airporting)

# %%
airporting
# Out:
# [{'_id': ObjectId('5b4a2643d580442b7c7607ef'),
#   'faa_site_number': '13487.*A',
#   'loc_id': 'ACY',
#   'airport_name': 'ATLANTIC CITY INTL',
#   'associated_city': 'ATLANTIC CITY',
#   'state': 'NJ',
#   'region': 'AEA',
#   'ado': 'HAR',
#   'use': 'PU',
#   'lat_dms': '39-27-27.3000N',
#   'long_dms': '074-34-37.8000W',
#   'lat_dd': 39.45758333,
#   'long_dd': -74.57716667,
#   'airport_ownership': 'PU',
#   'part_139': 'I C S 12/1974',
#   'npias_service_level': 'Primary',
#   'npias_hub_type': 'Small',
#   'airport_control_tower': 'Y',
#   'fuel': '100LLA    A++',
#   'other_services': 'CHTR',
#   'based_aircraft_total': 13,
#   'total_operations': 53506},
#  {'_id': ObjectId('5b4a2643d580442b7c7607f0'),
#   'faa_site_number': '14460.*A',
#   'loc_id': 'WWD',
#   'airport_name': 'CAPE MAY COUNTY',
#   'associated_city': 'WILDWOOD',
#   'state': 'NJ',
#   'region': 'AEA',
#   'ado': 'HAR',
#   'use': 'PU',
#   'lat_dms': '39-00-30.1300N',
#   'long_dms': '074-54-30.6400W',
# ...

# %%
edited = df.fillna(value="")
edited = 

edited
# Out:
#                           _id  ado airport_control_tower  \
# 0    5b4a2643d580442b7c7607ef  HAR                     Y
# 1    5b4a2643d580442b7c7607f0  HAR                     N
# 2    5b4a2643d580442b7c7607f1  HAR                     N
# 3    5b4a2643d580442b7c7607f2  HAR                     Y
# 4    5b4a2643d580442b7c7607f3  HAR                     N
# 5    5b4a2643d580442b7c7607f4  HAR                     N
# 6    5b4a2643d580442b7c7607f5  HAR                     N
# 7    5b4a2643d580442b7c7607f6  HAR                     N
# 8    5b4a2643d580442b7c7607f7  HAR                     N
# 9    5b4a2643d580442b7c7607f8  HAR                     N
# 10   5b4a2643d580442b7c7607f9  HAR                     N
# 11   5b4a2643d580442b7c7607fa  HAR                     Y
# 12   5b4a2643d580442b7c7607fb  NYC                     Y
# 13   5b4a2643d580442b7c7607fc  HAR                     N
# 14   5b4a2643d580442b7c7607fd  HAR                     N
# ...

# %%
client = pymongo.MongoClient("mongodb+srv://syverts1:Sn557239@cluster0.mongodb.net/test")
db = client.test
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# <ipython-input-8-7d36204aaedf> in <module>()
# ----> 1 client = pymongo.MongoClient("mongodb+srv://syverts1:Sn557239@cluster0.mongodb.net/test")
#       2 db = client.test
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py in __init__(self, host, port, document_class, tz_aware, connect, **kwargs)
#     466         for entity in host:
#     467             if "://" in entity:
# --> 468                 res = uri_parser.parse_uri(entity, port, warn=True)
#     469                 seeds.update(res["nodelist"])
#     470                 username = res["username"] or username
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\uri_parser.py in parse_uri(uri, default_port, validate, warn)
#     349     elif uri.startswith(SRV_SCHEME):
#     350         if not _HAVE_DNSPYTHON:
# ...
